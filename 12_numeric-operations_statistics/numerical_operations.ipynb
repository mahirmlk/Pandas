# %% [markdown]
# # Numerical Operations & Statistics
#
# Numerical analysis patterns commonly used in data analysis and time series work.

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'date': pd.date_range('2023-01-01', periods=6, freq='D'),
    'sales': [100, 120, 130, 125, 160, 170],
    'profit': [20, 25, 30, 28, 40, 45]
})

df = df.set_index('date')
df
# Out:
#             sales  profit
# date
# 2023-01-01    100      20
# 2023-01-02    120      25
# 2023-01-03    130      30
# 2023-01-04    125      28
# 2023-01-05    160      40
# 2023-01-06    170      45

# %% [markdown]
# ## Descriptive statistics

# %%
df.describe()
# Out:
#             sales     profit
# count    6.000000   6.000000
# mean   134.166667  31.333333
# std     26.156580   9.416298
# min    100.000000  20.000000
# 25%    121.250000  25.750000
# 50%    127.500000  29.000000
# 75%    152.500000  37.500000
# max    170.000000  45.000000

# %%
df.mean()
# Out:
# sales     134.166667
# profit     31.333333
# dtype: float64

# %%
df.std()
# Out:
# sales     26.156580
# profit     9.416298
# dtype: float64

# %% [markdown]
# ## Correlation & covariance

# %%
df.corr()
# Out:
#            sales    profit
# sales   1.000000  0.996083
# profit  0.996083  1.000000

# %%
df.cov()
# Out:
#              sales      profit
# sales   684.166667  245.333333
# profit  245.333333   88.666667

# %% [markdown]
# ## Quantiles

# %%
df.quantile(0.25)
# Out:
# sales     121.25
# profit     25.75
# Name: 0.25, dtype: float64

# %%
df.quantile([0.25, 0.5, 0.75])
# Out:
#        sales  profit
# 0.25  121.25   25.75
# 0.50  127.50   29.00
# 0.75  152.50   37.50

# %% [markdown]
# ## Rolling statistics

# %%
df.rolling(window=2).mean()
# Out:
#             sales  profit
# date
# 2023-01-01    NaN     NaN
# 2023-01-02  110.0    22.5
# 2023-01-03  125.0    27.5
# 2023-01-04  127.5    29.0
# 2023-01-05  142.5    34.0
# 2023-01-06  165.0    42.5

# %%
df['sales'].rolling(window=3).sum()
# Out:
# date
# 2023-01-01      NaN
# 2023-01-02      NaN
# 2023-01-03    350.0
# 2023-01-04    375.0
# 2023-01-05    415.0
# 2023-01-06    455.0
# Name: sales, dtype: float64

# %% [markdown]
# ## Expanding windows

# %%
df.expanding().mean()
# Out:
#                  sales     profit
# date
# 2023-01-01  100.000000  20.000000
# 2023-01-02  110.000000  22.500000
# 2023-01-03  116.666667  25.000000
# 2023-01-04  118.750000  25.750000
# 2023-01-05  127.000000  28.600000
# 2023-01-06  134.166667  31.333333

# %%
df['profit'].expanding().sum()
# Out:
# date
# 2023-01-01     20.0
# 2023-01-02     45.0
# 2023-01-03     75.0
# 2023-01-04    103.0
# 2023-01-05    143.0
# 2023-01-06    188.0
# Name: profit, dtype: float64

# %% [markdown]
# ## Window functions

# %%
df['sales_rank'] = df['sales'].rank()
df
# Out:
#             sales  profit  sales_rank
# date
# 2023-01-01    100      20         1.0
# 2023-01-02    120      25         2.0
# 2023-01-03    130      30         4.0
# 2023-01-04    125      28         3.0
# 2023-01-05    160      40         5.0
# 2023-01-06    170      45         6.0

# %%
df['rolling_zscore'] = (df['sales'] - df['sales'].rolling(3).mean()) / df['sales'].rolling(3).std()
df
# Out:
#             sales  profit  sales_rank  rolling_zscore
# date
# 2023-01-01    100      20         1.0             NaN
# 2023-01-02    120      25         2.0             NaN
# 2023-01-03    130      30         4.0        0.872872
# 2023-01-04    125      28         3.0        0.000000
# 2023-01-05    160      40         5.0        1.144586
# 2023-01-06    170      45         6.0        0.775880
