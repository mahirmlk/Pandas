# %% [markdown]
# # Sorting & Ranking
#
# Common patterns for ordering data and ranking values in Pandas.

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'city': ['Delhi', 'Mumbai', 'Chennai', 'Delhi', 'Mumbai'],
    'year': [2022, 2021, 2023, 2021, 2023],
    'sales': [120, 150, 90, 100, 160],
    'profit': [25, 35, 10, 20, 40]
})

df
# Out:
#       city  year  sales  profit
# 0    Delhi  2022    120      25
# 1   Mumbai  2021    150      35
# 2  Chennai  2023     90      10
# 3    Delhi  2021    100      20
# 4   Mumbai  2023    160      40

# %% [markdown]
# ## sort_values

# %%
df.sort_values('sales')
# Out:
#       city  year  sales  profit
# 2  Chennai  2023     90      10
# 3    Delhi  2021    100      20
# 0    Delhi  2022    120      25
# 1   Mumbai  2021    150      35
# 4   Mumbai  2023    160      40

# %%
df.sort_values('sales', ascending=False)
# Out:
#       city  year  sales  profit
# 4   Mumbai  2023    160      40
# 1   Mumbai  2021    150      35
# 0    Delhi  2022    120      25
# 3    Delhi  2021    100      20
# 2  Chennai  2023     90      10

# %%
df.sort_values(['city', 'sales'])
# Out:
#       city  year  sales  profit
# 2  Chennai  2023     90      10
# 3    Delhi  2021    100      20
# 0    Delhi  2022    120      25
# 1   Mumbai  2021    150      35
# 4   Mumbai  2023    160      40

# %%
df.sort_values(['city', 'sales'], ascending=[True, False])
# Out:
#       city  year  sales  profit
# 2  Chennai  2023     90      10
# 0    Delhi  2022    120      25
# 3    Delhi  2021    100      20
# 4   Mumbai  2023    160      40
# 1   Mumbai  2021    150      35

# %% [markdown]
# ## sort_index

# %%
df_indexed = df.set_index('city')
df_indexed
# Out:
#          year  sales  profit
# city
# Delhi    2022    120      25
# Mumbai   2021    150      35
# Chennai  2023     90      10
# Delhi    2021    100      20
# Mumbai   2023    160      40

# %%
df_indexed.sort_index()
# Out:
#          year  sales  profit
# city
# Chennai  2023     90      10
# Delhi    2022    120      25
# Delhi    2021    100      20
# Mumbai   2021    150      35
# Mumbai   2023    160      40

# %%
df_indexed.sort_index(ascending=False)
# Out:
#          year  sales  profit
# city
# Mumbai   2021    150      35
# Mumbai   2023    160      40
# Delhi    2022    120      25
# Delhi    2021    100      20
# Chennai  2023     90      10

# %% [markdown]
# ## Ranking data

# %%
df['sales_rank'] = df['sales'].rank()
df
# Out:
#       city  year  sales  profit  sales_rank
# 0    Delhi  2022    120      25         3.0
# 1   Mumbai  2021    150      35         4.0
# 2  Chennai  2023     90      10         1.0
# 3    Delhi  2021    100      20         2.0
# 4   Mumbai  2023    160      40         5.0

# %%
df['sales_rank_dense'] = df['sales'].rank(method='dense')
df
# Out:
#       city  year  sales  profit  sales_rank  sales_rank_dense
# 0    Delhi  2022    120      25         3.0               3.0
# 1   Mumbai  2021    150      35         4.0               4.0
# 2  Chennai  2023     90      10         1.0               1.0
# 3    Delhi  2021    100      20         2.0               2.0
# 4   Mumbai  2023    160      40         5.0               5.0

# %%
df['profit_rank_desc'] = df['profit'].rank(ascending=False)
df
# Out:
#       city  year  sales  profit  sales_rank  sales_rank_dense  \
# 0    Delhi  2022    120      25         3.0               3.0
# 1   Mumbai  2021    150      35         4.0               4.0
# 2  Chennai  2023     90      10         1.0               1.0
# 3    Delhi  2021    100      20         2.0               2.0
# 4   Mumbai  2023    160      40         5.0               5.0
#
#    profit_rank_desc
# 0               3.0
# 1               2.0
# 2               5.0
# 3               4.0
# 4               1.0

# %% [markdown]
# ## nlargest / nsmallest

# %%
df.nlargest(3, 'sales')
# Out:
#      city  year  sales  profit  sales_rank  sales_rank_dense  profit_rank_desc
# 4  Mumbai  2023    160      40         5.0               5.0               1.0
# 1  Mumbai  2021    150      35         4.0               4.0               2.0
# 0   Delhi  2022    120      25         3.0               3.0               3.0

# %%
df.nsmallest(2, 'profit')
# Out:
#       city  year  sales  profit  sales_rank  sales_rank_dense  \
# 2  Chennai  2023     90      10         1.0               1.0
# 3    Delhi  2021    100      20         2.0               2.0
#
#    profit_rank_desc
# 2               5.0
# 3               4.0

# %%
df.groupby('city')['sales'].nlargest(2)
# Out:
# city
# Chennai  2     90
# Delhi    0    120
#          3    100
# Mumbai   4    160
#          1    150
# Name: sales, dtype: int64
