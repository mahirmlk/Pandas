# %% [markdown]
# # Data Transformation

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'city': ['Delhi', 'Mumbai', 'Chennai', 'Delhi'],
    'sales': [100, 150, 90, 120],
    'profit': [20, 35, 10, 25]
})

df
# Out:
#       city  sales  profit
# 0    Delhi    100      20
# 1   Mumbai    150      35
# 2  Chennai     90      10
# 3    Delhi    120      25

# %% [markdown]
# ## Vectorized operations

# %%
df['sales'] * 1.1
# Out:
# 0    110.0
# 1    165.0
# 2     99.0
# 3    132.0
# Name: sales, dtype: float64

# %%
df['profit'] / df['sales']
# Out:
# 0    0.200000
# 1    0.233333
# 2    0.111111
# 3    0.208333
# dtype: float64

# %% [markdown]
# ## map

# %%
city_map = {'Delhi': 'DL', 'Mumbai': 'MH', 'Chennai': 'TN'}
df['city'].map(city_map)
# Out:
# 0    DL
# 1    MH
# 2    TN
# 3    DL
# Name: city, dtype: object

# %%
df['city'].map(lambda x: x.upper())
# Out:
# 0      DELHI
# 1     MUMBAI
# 2    CHENNAI
# 3      DELHI
# Name: city, dtype: object

# %% [markdown]
# ## apply (column-wise)

# %%
df[['sales', 'profit']].apply(np.mean)
# Out:
# sales     115.0
# profit     22.5
# dtype: float64

# %%
df[['sales', 'profit']].apply(lambda x: x.max() - x.min())
# Out:
# sales     60
# profit    25
# dtype: int64

# %% [markdown]
# ## apply (row-wise)

# %%
df.apply(lambda r: r['profit'] / r['sales'], axis=1)
# Out:
# 0    0.200000
# 1    0.233333
# 2    0.111111
# 3    0.208333
# dtype: float64

# %%
df.apply(lambda r: f"{r['city']}-{r['sales']}", axis=1)
# Out:
# 0     Delhi-100
# 1    Mumbai-150
# 2    Chennai-90
# 3     Delhi-120
# dtype: object

# %% [markdown]
# ## applymap

# %%
df[['sales', 'profit']].applymap(lambda x: x * 2)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2444\2715314503.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[['sales', 'profit']].applymap(lambda x: x * 2)
#    sales  profit
# 0    200      40
# 1    300      70
# 2    180      20
# 3    240      50

# %% [markdown]
# ## Conditional transformations

# %%
np.where(df['sales'] > 120, 'High', 'Low')
# Out:
# array(['Low', 'High', 'Low', 'Low'], dtype='<U4')

# %%
df['category'] = np.where(df['profit'] > 20, 'Good', 'Average')
df
# Out:
#       city  sales  profit category
# 0    Delhi    100      20  Average
# 1   Mumbai    150      35     Good
# 2  Chennai     90      10  Average
# 3    Delhi    120      25     Good

# %% [markdown]
# ## Column-wise vs row-wise

# %%
df[['sales', 'profit']].sum(axis=0)
# Out:
# sales     460
# profit     90
# dtype: int64

# %%
df[['sales', 'profit']].sum(axis=1)
# Out:
# 0    120
# 1    185
# 2    100
# 3    145
# dtype: int64
