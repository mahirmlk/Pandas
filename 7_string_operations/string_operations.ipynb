# %% [markdown]
# # String Operations
#
# Working with text data using Pandas string methods.

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'text': [
        '  Hello World  ',
        'Data-Science_101',
        'email:test@example.com',
        'Phone: +91-9876543210',
        None
    ]
})

df
# Out:
#                      text
# 0           Hello World
# 1        Data-Science_101
# 2  email:test@example.com
# 3   Phone: +91-9876543210
# 4                    None

# %% [markdown]
# ## str accessor

# %%
df['text'].str.lower()
# Out:
# 0             hello world
# 1          data-science_101
# 2    email:test@example.com
# 3     phone: +91-9876543210
# 4                      None
# Name: text, dtype: object

# %%
df['text'].str.upper()
# Out:
# 0             HELLO WORLD
# 1          DATA-SCIENCE_101
# 2    EMAIL:TEST@EXAMPLE.COM
# 3     PHONE: +91-9876543210
# 4                      None
# Name: text, dtype: object

# %%
df['text'].str.len()
# Out:
# 0    15.0
# 1    16.0
# 2    22.0
# 3    21.0
# 4     NaN
# Name: text, dtype: float64

# %% [markdown]
# ## String cleaning

# %%
df['text'].str.strip()
# Out:
# 0               Hello World
# 1          Data-Science_101
# 2    email:test@example.com
# 3     Phone: +91-9876543210
# 4                      None
# Name: text, dtype: object

# %%
df['text'].str.replace('-', ' ', regex=False)
# Out:
# 0             Hello World
# 1          Data Science_101
# 2    email:test@example.com
# 3     Phone: +91 9876543210
# 4                      None
# Name: text, dtype: object

# %%
df['text'].str.replace(r'[_:]', ' ', regex=True)
# Out:
# 0             Hello World
# 1          Data-Science 101
# 2    email test@example.com
# 3     Phone  +91-9876543210
# 4                      None
# Name: text, dtype: object

# %% [markdown]
# ## Pattern matching

# %%
df['text'].str.contains('Data', na=False)
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: text, dtype: bool

# %%
df['text'].str.startswith('email', na=False)
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: text, dtype: bool

# %%
df['text'].str.endswith('.com', na=False)
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: text, dtype: bool

# %% [markdown]
# ## Regular expressions

# %%
df['text'].str.findall(r'\d+')
# Out:
# 0                  []
# 1               [101]
# 2                  []
# 3    [91, 9876543210]
# 4                None
# Name: text, dtype: object

# %%
df['text'].str.replace(r'\d', 'X', regex=True)
# Out:
# 0             Hello World
# 1          Data-Science_XXX
# 2    email:test@example.com
# 3     Phone: +XX-XXXXXXXXXX
# 4                      None
# Name: text, dtype: object

# %% [markdown]
# ## Extracting text features

# %%
df['email'] = df['text'].str.extract(r'([\w.-]+@[\w.-]+)')
df
# Out:
#                      text             email
# 0           Hello World                 NaN
# 1        Data-Science_101               NaN
# 2  email:test@example.com  test@example.com
# 3   Phone: +91-9876543210               NaN
# 4                    None               NaN

# %%
df['digits'] = df['text'].str.extract(r'(\d+)')
df
# Out:
#                      text             email digits
# 0           Hello World                 NaN    NaN
# 1        Data-Science_101               NaN    101
# 2  email:test@example.com  test@example.com    NaN
# 3   Phone: +91-9876543210               NaN     91
# 4                    None               NaN    NaN

# %% [markdown]
# ## Splitting and joining strings

# %%
df['text'].str.split(' ')
# Out:
# 0      [, , Hello, World, , ]
# 1          [Data-Science_101]
# 2    [email:test@example.com]
# 3    [Phone:, +91-9876543210]
# 4                        None
# Name: text, dtype: object

# %%
df['text'].str.split(' ', expand=True)
# Out:
#                         0               1      2      3     4     5
# 0                                          Hello  World
# 1        Data-Science_101            None   None   None  None  None
# 2  email:test@example.com            None   None   None  None  None
# 3                  Phone:  +91-9876543210   None   None  None  None
# 4                    None            None   None   None  None  None

# %%
df['text'].str.split(':').str[0]
# Out:
# 0       Hello World
# 1    Data-Science_101
# 2               email
# 3               Phone
# 4                None
# Name: text, dtype: object

# %%
pd.Series(['DL', 'MH', 'TN']).str.cat(sep='-')
# Out:
# 'DL-MH-TN'
